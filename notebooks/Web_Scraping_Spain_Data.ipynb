# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
lista= pd.read_html("http://datosmacro.expansion.com/pib/espana", match='.+', flavor=None, header=None, index_col=None, skiprows=None, attrs=None, parse_dates=False, thousands=', ', encoding=None, decimal='.', converters=None, na_values=None, keep_default_na=True, displayed_only=True)

# %%
PIB_anual=lista[2]
PIB_per_capita=lista[3]

# %%
PIB_anual
# Out:
#     Fecha     PIB anual   PIB anual.1 Var. PIB (%)
# 0    2019  1.244.757M.€  1.393.505M.$         2,0%
# 1    2018  1.202.193M.€  1.427.533M.$         2,4%
# 2    2017  1.161.878M.€  1.317.104M.$         2,9%
# 3    2016  1.113.840M.€  1.237.998M.$         3,0%
# 4    2015  1.077.590M.€  1.199.688M.$         3,8%
# 5    2014  1.032.158M.€  1.379.100M.$         1,4%
# 6    2013  1.020.348M.€  1.362.261M.$        -1,4%
# 7    2012  1.031.099M.€  1.336.789M.$        -3,0%
# 8    2011  1.063.763M.€  1.489.755M.$        -0,8%
# 9    2010  1.072.709M.€  1.434.184M.$         0,2%
# 10   2009  1.069.323M.€  1.503.409M.$        -3,8%
# 11   2008  1.109.541M.€  1.641.514M.$         0,9%
# 12   2007  1.075.539M.€  1.481.397M.$         3,6%
# 13   2006  1.003.823M.€  1.265.678M.$         4,1%
# 14   2005    927.357M.€  1.158.348M.$         3,7%
# 15   2004    859.437M.€  1.071.036M.$         3,1%
# 16   2003    802.266M.€    908.628M.$         3,0%
# ...
